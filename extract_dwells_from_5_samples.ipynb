# %% [markdown]
# # Extract Dwells from all Samples
#
# Chris Kimmel
# 7/31/2020
#
# The purpose of this notebook is to extract per-read per-position dwell times from 5 fast5 base-directories (called "fast5 basedirs" in the Tombo framework):
# * `/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_A/Trizol_A_8K_single_fast5`
# * `/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_B/Trizol_B_8K_single_fast5`
# * `/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_C/Trizol_C_8K_single_fast5`
# * `/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_OLD/Trizol_OLD_8K_single_fast5`
# * (An IVT control fast5 basedir, the path of which I don't know yet)
#
# All these data files are stored under Gabby Lee's home directory on the OSC Supercomputing Cluster
#
# The dwell-times will be extracted to CSV form - one CSV file per fast5 basedir.
# These CSV files will have one row for every read id, and one column for every nucleotide position on the reference genome.
# (Nucleotide positions on the reference genome will use *zero-based* indexing.)
#
# This reference genome is currently stored at `/fs/project/PAS1405/General/Kimmel_Chris/RNA_section__454_9627.fa`
# (under Chris Kimmel's home directory on the OSC Supercomputing Cluster).
# It was used to resquiggle all the fast5 files touched in this notebook.
# The column names in the CSV ouput to this notebook are *zero-based* indexes into this reference genome.

# %%
import os
import numpy as np
import pandas as pd
import h5py

# %%
# define constants

paths = {'A':'/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_A/Trizol_A_8K_single_fast5',
         'B':'/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_B/Trizol_B_8K_single_fast5',
         'C':'/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_C/Trizol_C_8K_single_fast5',
         'OLD':'/fs/project/PAS1405/GabbyLee/project/m6A_modif/sequencing_data/Trizol_OLD/Trizol_OLD_8K_single_fast5',
         'IVT':'/fs/project/PAS1405/GabbyLee/project/m6A_modif/ctrl_data_set/data_Olivier/f1f2_GL'}
reference_path = '/fs/project/PAS1405/General/Kimmel_Chris/RNA_section__454_9627.fa'
# return dwell times from position numbers between min_position (inclusive) and max_position (exclusive)
min_position = 0
max_position = 9300

# %%
def get_df_from_basedir(basedir_path):
    '''
    This function returns a pandas dataframe of per-read per-position dwell
    times. The rows are labeled by read ids and the columns are labeled by
    INTEGER position numbers. (Numbers are zero-based indexes into the reference
    genome.)
    
    Args:
        basedir_path (str): filepath to a fast5 basedir
    
    Returns:
        pd.DataFrame: a pandas dataframe of per-read per-position dwell-times
    '''
    fast5_name_list = os.listdir(basedir_path)
    fast5_path_list = [os.path.join(basedir_path, name) for name in os.listdir(basedir_path)]
    
    row_list = []
    weird_occurrences = 0
    for fast5_name, fast5_path in zip(fast5_name_list, fast5_path_list):
        try:
            with h5py.File(fast5_path, 'r') as file:
                # The following lines of code shouldn't be used on other fast5s.
                # At least, not without checking some assumptions.

                # Extract info from fast5
                basecall_subgroup = file['/Analyses/RawGenomeCorrected_000/BaseCalled_template']
                events = basecall_subgroup['Events']
                mapped_start = basecall_subgroup['Alignment'].attrs['mapped_start']
                num_events = len(events)

                # This will become a row in our dataframe
                lengths = events['length']
                event_based_index = np.arange(num_events)
                genome_based_index = event_based_index + mapped_start # ZERO-BASED!
                future_row = (
                    pd.Series(lengths, index=genome_based_index)
                    .rename(fast5_name) # this will become the future row name
                )
                row_list.append(future_row)
        except KeyError:
            pass # This fast5 probably failed resquiggling
        except IOError:
            weird_occurrences += 1
            pass # Sometimes
            
    if weird_occurrences > 1: # allow 1 corrupted file before complaining
        print('Some of the files couldn\'t be opened: ' + str(weird_occurrences))
    
    return pd.concat(row_list, axis=1).T # uses default axis=0, join=outer

display(get_df_from_basedir(paths['A']))
# Out:
#                                             9     10    11    12    13    \
# 13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5   NaN   NaN   NaN   NaN  14.0
# 1c498e5b-5e93-4cbe-baf2-8032a2e20ccb.fast5   NaN   NaN   NaN   NaN   NaN
# ebf6a522-8df0-48a9-a0ef-f4dcdde5339f.fast5   NaN   NaN   NaN   NaN   NaN
# b76ab61c-db0f-45d5-a65a-b40ce1296342.fast5   NaN   NaN   NaN   NaN   NaN
# 01f25e05-0219-430f-bc26-cb3948023adf.fast5   NaN   NaN   NaN   NaN   NaN
# e88e4d16-3908-4d11-8c94-fb64ad54266d.fast5   NaN   NaN   NaN   NaN   NaN
# 92f22b41-79b1-461f-b468-394d5352550d.fast5   NaN   NaN   NaN   NaN   NaN
# 1b050b90-add3-49b1-b6ea-d4c2a488817c.fast5   NaN   NaN   NaN   NaN   NaN
# 6348393f-6959-403b-a9d5-23b2ad7bd170.fast5   NaN   NaN   NaN   NaN   NaN
# 2beb0736-f2a1-44ad-9e3b-f8f2a99c940b.fast5   NaN   NaN   NaN   NaN   NaN
# 43a05c30-a583-4f33-9fbe-33623d874c67.fast5   NaN   NaN   NaN   NaN   NaN
# d31e9abf-0c52-4364-95ce-b4e30d8f1439.fast5   NaN   NaN   NaN   NaN   NaN
# e3d1a174-b44c-45f1-a4ed-5431930e6baa.fast5   NaN   NaN   NaN   NaN   NaN
# 1689f4d6-0725-4e84-bc2a-ff66734cd7f6.fast5   NaN   NaN   NaN   NaN   NaN
# f29865cd-8625-4799-8ad3-78a6d86ee762.fast5   NaN   NaN   NaN   NaN   NaN
# 074b8b7f-99ce-4403-ae62-1fdddc60f7a6.fast5   NaN   NaN   NaN   NaN   NaN
# ae7f89df-6b11-4b5e-8435-119904bc67e3.fast5   NaN   NaN   NaN   NaN   NaN
# 0f3275f2-a2bf-4ba2-873d-207e6b5e1c6d.fast5   NaN   NaN   NaN   NaN   NaN
# 2b42461d-4c3f-40ca-be61-99e4e1e2b64e.fast5   NaN   NaN   NaN   NaN   NaN
# fbadf6f3-79a5-4d2e-a332-74f00e139c4b.fast5   NaN   NaN   NaN   NaN   NaN
# 57826bc6-3acb-4902-b5ff-ce8331550b57.fast5   NaN   NaN   NaN   NaN   NaN
# 2828b3be-4685-431b-a662-a8343018dcb8.fast5   NaN   NaN   NaN   NaN   NaN
# eaa433b8-08af-4a24-b27c-2eb4ea7d9592.fast5   NaN   NaN   NaN   NaN   NaN
# b4bd83d6-7c9a-41ed-9e1a-7259cb3a50e0.fast5   NaN   NaN   NaN   NaN   NaN
# 888f41f3-4bcc-4327-bc45-5c9262f71997.fast5   NaN   NaN   NaN   NaN   NaN
# 9282c375-74df-42cb-9a85-b2bd64a1eaaa.fast5   NaN   NaN   NaN   NaN   NaN
# 2c301762-8522-4c5e-a077-69eb62370686.fast5   NaN   NaN   NaN   NaN   NaN
# dd7793fb-e022-41ae-ba21-aab2d38d3efc.fast5   NaN   NaN   NaN   NaN   NaN
# 754a5893-35a5-45e6-afac-4f503831c8a2.fast5   NaN   NaN   NaN   NaN   NaN
# d0cf16a5-ec5e-4b77-8653-a6e3fd3a3ef6.fast5   NaN   NaN   NaN   NaN   NaN
# ...                                          ...   ...   ...   ...   ...
# 8c63db92-d785-4299-a11b-da53a17994d0.fast5   NaN   NaN   NaN   NaN   NaN
# 69e49417-ac25-4221-9569-86ea8510978e.fast5   NaN   NaN   NaN   NaN   NaN
# b6ec3349-45c9-4406-83ae-66a3bcdbc763.fast5   NaN   NaN   NaN   NaN   NaN
# d0c7ac07-4705-4476-98de-5155fa1ede70.fast5   NaN   NaN   NaN   NaN   NaN
# 560ed0f2-d0f8-40f8-a55f-886b1a9c04f1.fast5   NaN   NaN   NaN   NaN   6.0
# da406fc7-da74-46cf-83e5-3a8cb2986e58.fast5   NaN   NaN   NaN   NaN   NaN
# 43e2551c-ef59-4db6-8e14-cc2abd8df31c.fast5   NaN   NaN   NaN   NaN   NaN
# 5e60f3d8-71d5-41bc-8e33-334a3def9209.fast5   NaN   NaN   NaN   NaN   NaN
# c0ab8740-b4df-4f57-b615-4f52d6116455.fast5   NaN   NaN   NaN   NaN   NaN
# c1afd570-ed94-41d8-a0fc-929d65ac813f.fast5   NaN   NaN   NaN   NaN   NaN
# 51d12b59-17db-42f9-a6a9-bbbc3cd341ee.fast5   NaN   NaN   NaN   NaN   NaN
# 3534bb36-5357-43e7-82bf-9f220a55ac98.fast5   NaN   NaN   NaN   NaN   NaN
# ddc27333-d9ab-4835-af7b-368e5390a405.fast5   NaN   NaN   NaN   NaN   NaN
# 6a16700c-b658-49a3-8662-832b87a47804.fast5   NaN   NaN   NaN   NaN   NaN
# 23c90439-1125-4a84-bf58-a236220b3e56.fast5   NaN   NaN   NaN   NaN   NaN
# 91da9691-5adf-4294-ae9d-40221286e342.fast5   NaN   NaN   NaN   NaN   NaN
# ecb902df-13aa-42bc-981f-155248106ae7.fast5   NaN   NaN   NaN   NaN   NaN
# 5e4c212f-080a-4165-ab10-c42df484a5d0.fast5   NaN   NaN   NaN   NaN   NaN
# d858aa09-a3b0-4b18-8205-7d006bd1db15.fast5   NaN   NaN   NaN   NaN   NaN
# 336f5264-d1a6-4d71-b1cc-4220523e2af2.fast5   NaN   NaN   NaN   NaN   NaN
# a1fe1777-ac94-4832-9daa-6edbdecb7fde.fast5   NaN   NaN   NaN   NaN   NaN
# 45d11beb-91ab-49f4-86d9-142bfeccb209.fast5   NaN   NaN   NaN   NaN   NaN
# 4936838e-9340-4497-bcf7-d41647d21372.fast5   NaN   NaN   NaN   NaN   NaN
# a8b78ea7-159b-42bf-a2e5-98bc26987de2.fast5   NaN   NaN   NaN   NaN   NaN
# 3f74febf-1ec5-479f-b2b4-522fad358daa.fast5   NaN   NaN   NaN   NaN   NaN
# 255e006f-16ca-433e-8649-3aada74d9d1c.fast5   NaN   NaN   NaN   NaN   NaN
# d595c69e-0b1c-412f-a40e-c479a43f5300.fast5   NaN   NaN   NaN   NaN   NaN
# e3a14f4c-60a5-4cdf-8870-470a49ed093b.fast5   NaN   NaN   NaN   NaN   NaN
# 06ef4d57-98a5-4a88-9e01-a3a872340788.fast5   NaN   NaN   NaN   NaN   NaN
# 4f081c6d-c0c4-4488-a851-cd8a7f284e91.fast5   NaN   NaN   NaN   NaN   6.0
#
#                                             14    15    16    17    18    \
# 13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5   6.0  19.0   6.0   8.0   6.0
# 1c498e5b-5e93-4cbe-baf2-8032a2e20ccb.fast5   NaN   2.0   9.0  28.0   6.0
# ebf6a522-8df0-48a9-a0ef-f4dcdde5339f.fast5   NaN   NaN   NaN   NaN   NaN
# b76ab61c-db0f-45d5-a65a-b40ce1296342.fast5   NaN   6.0  25.0  59.0   6.0
# 01f25e05-0219-430f-bc26-cb3948023adf.fast5   NaN   NaN   NaN   NaN   NaN
# e88e4d16-3908-4d11-8c94-fb64ad54266d.fast5   NaN   NaN   NaN   NaN   NaN
# 92f22b41-79b1-461f-b468-394d5352550d.fast5   NaN   6.0  46.0   7.0   6.0
# 1b050b90-add3-49b1-b6ea-d4c2a488817c.fast5   NaN   NaN   NaN   NaN   NaN
# 6348393f-6959-403b-a9d5-23b2ad7bd170.fast5   NaN   NaN   NaN   NaN   NaN
# 2beb0736-f2a1-44ad-9e3b-f8f2a99c940b.fast5   NaN   NaN   NaN   NaN   NaN
# 43a05c30-a583-4f33-9fbe-33623d874c67.fast5   NaN   NaN   NaN   NaN   NaN
# d31e9abf-0c52-4364-95ce-b4e30d8f1439.fast5   NaN   NaN   NaN   NaN   NaN
# e3d1a174-b44c-45f1-a4ed-5431930e6baa.fast5   NaN   NaN   NaN   NaN   NaN
# 1689f4d6-0725-4e84-bc2a-ff66734cd7f6.fast5   7.0   6.0  21.0  19.0   6.0
# f29865cd-8625-4799-8ad3-78a6d86ee762.fast5   NaN   6.0  36.0  27.0   6.0
# 074b8b7f-99ce-4403-ae62-1fdddc60f7a6.fast5   NaN   NaN   NaN   NaN   NaN
# ae7f89df-6b11-4b5e-8435-119904bc67e3.fast5   NaN   NaN   NaN   NaN   NaN
# 0f3275f2-a2bf-4ba2-873d-207e6b5e1c6d.fast5   NaN   NaN   NaN   NaN   NaN
# 2b42461d-4c3f-40ca-be61-99e4e1e2b64e.fast5   NaN  29.0  26.0   7.0   6.0
# fbadf6f3-79a5-4d2e-a332-74f00e139c4b.fast5   NaN   NaN   NaN   NaN   NaN
# 57826bc6-3acb-4902-b5ff-ce8331550b57.fast5  12.0   6.0  21.0  32.0   6.0
# 2828b3be-4685-431b-a662-a8343018dcb8.fast5   NaN   NaN   NaN   NaN   NaN
# eaa433b8-08af-4a24-b27c-2eb4ea7d9592.fast5   NaN   NaN   NaN   NaN   NaN
# b4bd83d6-7c9a-41ed-9e1a-7259cb3a50e0.fast5   NaN   NaN   NaN   NaN   NaN
# 888f41f3-4bcc-4327-bc45-5c9262f71997.fast5   NaN   NaN   NaN   NaN   NaN
# 9282c375-74df-42cb-9a85-b2bd64a1eaaa.fast5   NaN   NaN   NaN   6.0  11.0
# 2c301762-8522-4c5e-a077-69eb62370686.fast5   NaN   NaN   NaN   NaN   NaN
# dd7793fb-e022-41ae-ba21-aab2d38d3efc.fast5  34.0   6.0  15.0  42.0   6.0
# 754a5893-35a5-45e6-afac-4f503831c8a2.fast5   NaN   NaN   NaN   NaN   NaN
# d0cf16a5-ec5e-4b77-8653-a6e3fd3a3ef6.fast5   NaN   NaN   NaN   NaN   2.0
# ...                                          ...   ...   ...   ...   ...
# 8c63db92-d785-4299-a11b-da53a17994d0.fast5   NaN   NaN   NaN   NaN   NaN
# 69e49417-ac25-4221-9569-86ea8510978e.fast5   6.0   6.0  13.0  10.0   6.0
# b6ec3349-45c9-4406-83ae-66a3bcdbc763.fast5   NaN  11.0  30.0  28.0   6.0
# d0c7ac07-4705-4476-98de-5155fa1ede70.fast5   NaN   2.0   4.0  16.0   6.0
# 560ed0f2-d0f8-40f8-a55f-886b1a9c04f1.fast5  11.0   6.0  12.0  32.0   6.0
# da406fc7-da74-46cf-83e5-3a8cb2986e58.fast5  55.0  20.0  13.0   4.0   2.0
# 43e2551c-ef59-4db6-8e14-cc2abd8df31c.fast5   NaN   NaN   NaN   NaN   NaN
# 5e60f3d8-71d5-41bc-8e33-334a3def9209.fast5   7.0  16.0  43.0  17.0   6.0
# c0ab8740-b4df-4f57-b615-4f52d6116455.fast5   NaN   6.0  49.0  13.0   6.0
# c1afd570-ed94-41d8-a0fc-929d65ac813f.fast5   NaN   6.0  39.0  56.0   6.0
# 51d12b59-17db-42f9-a6a9-bbbc3cd341ee.fast5   NaN   NaN   NaN   NaN   NaN
# 3534bb36-5357-43e7-82bf-9f220a55ac98.fast5   NaN   NaN  33.0   8.0   6.0
# ddc27333-d9ab-4835-af7b-368e5390a405.fast5   NaN   NaN   NaN  24.0   6.0
# 6a16700c-b658-49a3-8662-832b87a47804.fast5   6.0  13.0   6.0  14.0   6.0
# 23c90439-1125-4a84-bf58-a236220b3e56.fast5   NaN   NaN   NaN   NaN   NaN
# 91da9691-5adf-4294-ae9d-40221286e342.fast5  34.0   6.0  39.0  25.0   6.0
# ecb902df-13aa-42bc-981f-155248106ae7.fast5  28.0   6.0  12.0  11.0   6.0
# 5e4c212f-080a-4165-ab10-c42df484a5d0.fast5   NaN   NaN   NaN   NaN   NaN
# d858aa09-a3b0-4b18-8205-7d006bd1db15.fast5  39.0  12.0  19.0  32.0   6.0
# 336f5264-d1a6-4d71-b1cc-4220523e2af2.fast5   NaN   6.0  12.0  10.0   6.0
# a1fe1777-ac94-4832-9daa-6edbdecb7fde.fast5   9.0  23.0  51.0  39.0   6.0
# 45d11beb-91ab-49f4-86d9-142bfeccb209.fast5  17.0   6.0   6.0  11.0   8.0
# 4936838e-9340-4497-bcf7-d41647d21372.fast5   NaN   NaN   NaN   NaN   NaN
# a8b78ea7-159b-42bf-a2e5-98bc26987de2.fast5   NaN   NaN   NaN   NaN   NaN
# 3f74febf-1ec5-479f-b2b4-522fad358daa.fast5   NaN   NaN   NaN   NaN   NaN
# 255e006f-16ca-433e-8649-3aada74d9d1c.fast5   NaN   NaN   NaN   NaN   NaN
# d595c69e-0b1c-412f-a40e-c479a43f5300.fast5  14.0  28.0   6.0   6.0   6.0
# e3a14f4c-60a5-4cdf-8870-470a49ed093b.fast5   6.0  15.0  22.0   6.0   6.0
# 06ef4d57-98a5-4a88-9e01-a3a872340788.fast5   8.0   6.0  35.0  19.0   6.0
# 4f081c6d-c0c4-4488-a851-cd8a7f284e91.fast5   6.0  32.0  28.0   6.0   6.0
#
#                                             ...   9161   9162   9163  9164  \
# 13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5  ...   67.0   73.0  104.0  64.0
# 1c498e5b-5e93-4cbe-baf2-8032a2e20ccb.fast5  ...   33.0   66.0    8.0  17.0
# ebf6a522-8df0-48a9-a0ef-f4dcdde5339f.fast5  ...    NaN    NaN    NaN   NaN
# b76ab61c-db0f-45d5-a65a-b40ce1296342.fast5  ...    6.0   15.0   14.0  30.0
# 01f25e05-0219-430f-bc26-cb3948023adf.fast5  ...    NaN    NaN    NaN   NaN
# e88e4d16-3908-4d11-8c94-fb64ad54266d.fast5  ...   58.0   39.0   30.0  17.0
# 92f22b41-79b1-461f-b468-394d5352550d.fast5  ...   25.0   40.0   45.0  19.0
# 1b050b90-add3-49b1-b6ea-d4c2a488817c.fast5  ...   23.0   60.0   43.0  15.0
# 6348393f-6959-403b-a9d5-23b2ad7bd170.fast5  ...   29.0  104.0   11.0  29.0
# 2beb0736-f2a1-44ad-9e3b-f8f2a99c940b.fast5  ...   27.0   37.0   30.0  14.0
# 43a05c30-a583-4f33-9fbe-33623d874c67.fast5  ...    6.0    NaN    NaN   NaN
# d31e9abf-0c52-4364-95ce-b4e30d8f1439.fast5  ...    NaN    NaN    NaN   NaN
# e3d1a174-b44c-45f1-a4ed-5431930e6baa.fast5  ...   63.0    7.0   86.0   8.0
# 1689f4d6-0725-4e84-bc2a-ff66734cd7f6.fast5  ...    NaN    NaN    NaN   NaN
# f29865cd-8625-4799-8ad3-78a6d86ee762.fast5  ...   79.0  107.0   16.0   6.0
# 074b8b7f-99ce-4403-ae62-1fdddc60f7a6.fast5  ...   71.0   99.0   70.0   8.0
# ae7f89df-6b11-4b5e-8435-119904bc67e3.fast5  ...   24.0  168.0    6.0  58.0
# 0f3275f2-a2bf-4ba2-873d-207e6b5e1c6d.fast5  ...   13.0   24.0   25.0   6.0
# 2b42461d-4c3f-40ca-be61-99e4e1e2b64e.fast5  ...   10.0   19.0   19.0  17.0
# fbadf6f3-79a5-4d2e-a332-74f00e139c4b.fast5  ...   25.0   24.0    8.0  28.0
# 57826bc6-3acb-4902-b5ff-ce8331550b57.fast5  ...   20.0   25.0   22.0  20.0
# 2828b3be-4685-431b-a662-a8343018dcb8.fast5  ...    NaN    NaN    NaN   NaN
# eaa433b8-08af-4a24-b27c-2eb4ea7d9592.fast5  ...   41.0   75.0   12.0  21.0
# b4bd83d6-7c9a-41ed-9e1a-7259cb3a50e0.fast5  ...   22.0   66.0   33.0   6.0
# 888f41f3-4bcc-4327-bc45-5c9262f71997.fast5  ...    NaN    NaN    NaN   NaN
# 9282c375-74df-42cb-9a85-b2bd64a1eaaa.fast5  ...   27.0   30.0   25.0  26.0
# 2c301762-8522-4c5e-a077-69eb62370686.fast5  ...   21.0    6.0    6.0  22.0
# dd7793fb-e022-41ae-ba21-aab2d38d3efc.fast5  ...   73.0   50.0   18.0  80.0
# 754a5893-35a5-45e6-afac-4f503831c8a2.fast5  ...   15.0   58.0    6.0  66.0
# d0cf16a5-ec5e-4b77-8653-a6e3fd3a3ef6.fast5  ...    NaN    NaN    NaN   NaN
# ...                                         ...    ...    ...    ...   ...
# 8c63db92-d785-4299-a11b-da53a17994d0.fast5  ...    NaN    NaN    NaN   NaN
# 69e49417-ac25-4221-9569-86ea8510978e.fast5  ...   51.0   66.0   13.0  49.0
# b6ec3349-45c9-4406-83ae-66a3bcdbc763.fast5  ...    NaN    NaN    NaN   NaN
# d0c7ac07-4705-4476-98de-5155fa1ede70.fast5  ...    NaN    NaN    NaN   NaN
# 560ed0f2-d0f8-40f8-a55f-886b1a9c04f1.fast5  ...   18.0   61.0   24.0  18.0
# da406fc7-da74-46cf-83e5-3a8cb2986e58.fast5  ...   13.0    6.0   18.0   NaN
# 43e2551c-ef59-4db6-8e14-cc2abd8df31c.fast5  ...    NaN    NaN    NaN   NaN
# 5e60f3d8-71d5-41bc-8e33-334a3def9209.fast5  ...    9.0   53.0   55.0   6.0
# c0ab8740-b4df-4f57-b615-4f52d6116455.fast5  ...    NaN    NaN    NaN   NaN
# c1afd570-ed94-41d8-a0fc-929d65ac813f.fast5  ...   14.0   42.0   45.0  20.0
# 51d12b59-17db-42f9-a6a9-bbbc3cd341ee.fast5  ...   19.0   63.0    7.0  18.0
# 3534bb36-5357-43e7-82bf-9f220a55ac98.fast5  ...   29.0   58.0   26.0  34.0
# ddc27333-d9ab-4835-af7b-368e5390a405.fast5  ...    NaN    NaN    NaN   NaN
# 6a16700c-b658-49a3-8662-832b87a47804.fast5  ...    NaN    NaN    NaN   NaN
# 23c90439-1125-4a84-bf58-a236220b3e56.fast5  ...   12.0   50.0   12.0  10.0
# 91da9691-5adf-4294-ae9d-40221286e342.fast5  ...   31.0   38.0   14.0  26.0
# ecb902df-13aa-42bc-981f-155248106ae7.fast5  ...   28.0   28.0    7.0  29.0
# 5e4c212f-080a-4165-ab10-c42df484a5d0.fast5  ...   36.0  193.0   20.0  12.0
# d858aa09-a3b0-4b18-8205-7d006bd1db15.fast5  ...    NaN    NaN    NaN   NaN
# 336f5264-d1a6-4d71-b1cc-4220523e2af2.fast5  ...   34.0   52.0    9.0   6.0
# a1fe1777-ac94-4832-9daa-6edbdecb7fde.fast5  ...   89.0   54.0    6.0  14.0
# 45d11beb-91ab-49f4-86d9-142bfeccb209.fast5  ...   37.0   65.0    7.0  42.0
# 4936838e-9340-4497-bcf7-d41647d21372.fast5  ...    NaN    NaN    NaN   NaN
# a8b78ea7-159b-42bf-a2e5-98bc26987de2.fast5  ...   32.0    6.0   34.0  13.0
# 3f74febf-1ec5-479f-b2b4-522fad358daa.fast5  ...   39.0   66.0    6.0  13.0
# 255e006f-16ca-433e-8649-3aada74d9d1c.fast5  ...    NaN    NaN    NaN   NaN
# d595c69e-0b1c-412f-a40e-c479a43f5300.fast5  ...   41.0   43.0   14.0  48.0
# e3a14f4c-60a5-4cdf-8870-470a49ed093b.fast5  ...   17.0   40.0    6.0  51.0
# 06ef4d57-98a5-4a88-9e01-a3a872340788.fast5  ...   41.0   57.0   34.0  37.0
# 4f081c6d-c0c4-4488-a851-cd8a7f284e91.fast5  ...    NaN    NaN    NaN   NaN
#
#                                             9165  9166  9167   9168   9169  \
# 13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5  22.0  55.0  26.0    6.0  124.0
# 1c498e5b-5e93-4cbe-baf2-8032a2e20ccb.fast5   6.0  41.0  12.0    6.0   15.0
# ebf6a522-8df0-48a9-a0ef-f4dcdde5339f.fast5   NaN   NaN   NaN    NaN    NaN
# b76ab61c-db0f-45d5-a65a-b40ce1296342.fast5   6.0  30.0  51.0   50.0   66.0
# 01f25e05-0219-430f-bc26-cb3948023adf.fast5   NaN   NaN   NaN    NaN    NaN
# e88e4d16-3908-4d11-8c94-fb64ad54266d.fast5   7.0  26.0   6.0    NaN    NaN
# 92f22b41-79b1-461f-b468-394d5352550d.fast5   6.0  20.0  13.0    6.0   77.0
# 1b050b90-add3-49b1-b6ea-d4c2a488817c.fast5   7.0  30.0  25.0    6.0   81.0
# 6348393f-6959-403b-a9d5-23b2ad7bd170.fast5   6.0  19.0  14.0    6.0   48.0
# 2beb0736-f2a1-44ad-9e3b-f8f2a99c940b.fast5   6.0  21.0  23.0  164.0    NaN
# 43a05c30-a583-4f33-9fbe-33623d874c67.fast5   NaN   NaN   NaN    NaN    NaN
# d31e9abf-0c52-4364-95ce-b4e30d8f1439.fast5   NaN   NaN   NaN    NaN    NaN
# e3d1a174-b44c-45f1-a4ed-5431930e6baa.fast5  11.0   6.0  17.0    NaN    NaN
# 1689f4d6-0725-4e84-bc2a-ff66734cd7f6.fast5   NaN   NaN   NaN    NaN    NaN
# f29865cd-8625-4799-8ad3-78a6d86ee762.fast5  38.0  14.0   6.0    NaN    NaN
# 074b8b7f-99ce-4403-ae62-1fdddc60f7a6.fast5  14.0  12.0  19.0    NaN    NaN
# ae7f89df-6b11-4b5e-8435-119904bc67e3.fast5   6.0  18.0  14.0    6.0   37.0
# 0f3275f2-a2bf-4ba2-873d-207e6b5e1c6d.fast5  14.0   6.0  21.0    NaN    NaN
# 2b42461d-4c3f-40ca-be61-99e4e1e2b64e.fast5  10.0  20.0  62.0    NaN    NaN
# fbadf6f3-79a5-4d2e-a332-74f00e139c4b.fast5  17.0  48.0  70.0    NaN    NaN
# 57826bc6-3acb-4902-b5ff-ce8331550b57.fast5  13.0  15.0  12.0    6.0   71.0
# 2828b3be-4685-431b-a662-a8343018dcb8.fast5   NaN   NaN   NaN    NaN    NaN
# eaa433b8-08af-4a24-b27c-2eb4ea7d9592.fast5   9.0  45.0  12.0  109.0    NaN
# b4bd83d6-7c9a-41ed-9e1a-7259cb3a50e0.fast5   8.0  34.0  70.0    6.0  145.0
# 888f41f3-4bcc-4327-bc45-5c9262f71997.fast5   NaN   NaN   NaN    NaN    NaN
# 9282c375-74df-42cb-9a85-b2bd64a1eaaa.fast5   6.0  22.0   7.0    NaN    NaN
# 2c301762-8522-4c5e-a077-69eb62370686.fast5  22.0  29.0  16.0    6.0   97.0
# dd7793fb-e022-41ae-ba21-aab2d38d3efc.fast5  20.0  22.0  13.0    6.0   29.0
# 754a5893-35a5-45e6-afac-4f503831c8a2.fast5  21.0  52.0  23.0    NaN    NaN
# d0cf16a5-ec5e-4b77-8653-a6e3fd3a3ef6.fast5   NaN   NaN   NaN    NaN    NaN
# ...                                          ...   ...   ...    ...    ...
# 8c63db92-d785-4299-a11b-da53a17994d0.fast5   NaN   NaN   NaN    NaN    NaN
# 69e49417-ac25-4221-9569-86ea8510978e.fast5   6.0  19.0  12.0    NaN    NaN
# b6ec3349-45c9-4406-83ae-66a3bcdbc763.fast5   NaN   NaN   NaN    NaN    NaN
# d0c7ac07-4705-4476-98de-5155fa1ede70.fast5   NaN   NaN   NaN    NaN    NaN
# 560ed0f2-d0f8-40f8-a55f-886b1a9c04f1.fast5   9.0  22.0   6.0    NaN    NaN
# da406fc7-da74-46cf-83e5-3a8cb2986e58.fast5   NaN   NaN   NaN    NaN    NaN
# 43e2551c-ef59-4db6-8e14-cc2abd8df31c.fast5   NaN   NaN   NaN    NaN    NaN
# 5e60f3d8-71d5-41bc-8e33-334a3def9209.fast5  10.0  95.0  12.0    NaN    NaN
# c0ab8740-b4df-4f57-b615-4f52d6116455.fast5   NaN   NaN   NaN    NaN    NaN
# c1afd570-ed94-41d8-a0fc-929d65ac813f.fast5   7.0  26.0   6.0    6.0   11.0
# 51d12b59-17db-42f9-a6a9-bbbc3cd341ee.fast5   6.0  15.0  16.0    6.0   62.0
# 3534bb36-5357-43e7-82bf-9f220a55ac98.fast5  48.0  19.0  26.0    6.0   27.0
# ddc27333-d9ab-4835-af7b-368e5390a405.fast5   NaN   NaN   NaN    NaN    NaN
# 6a16700c-b658-49a3-8662-832b87a47804.fast5   NaN   NaN   NaN    NaN    NaN
# 23c90439-1125-4a84-bf58-a236220b3e56.fast5   6.0  12.0  13.0    6.0   17.0
# 91da9691-5adf-4294-ae9d-40221286e342.fast5  21.0  19.0  12.0    6.0   53.0
# ecb902df-13aa-42bc-981f-155248106ae7.fast5   9.0  55.0  13.0    NaN    NaN
# 5e4c212f-080a-4165-ab10-c42df484a5d0.fast5   9.0  37.0  17.0   73.0    NaN
# d858aa09-a3b0-4b18-8205-7d006bd1db15.fast5   NaN   NaN   NaN    NaN    NaN
# 336f5264-d1a6-4d71-b1cc-4220523e2af2.fast5  22.0  15.0  33.0    NaN    NaN
# a1fe1777-ac94-4832-9daa-6edbdecb7fde.fast5  12.0   6.0  16.0    NaN    NaN
# 45d11beb-91ab-49f4-86d9-142bfeccb209.fast5   6.0  30.0  14.0    6.0  124.0
# 4936838e-9340-4497-bcf7-d41647d21372.fast5   NaN   NaN   NaN    NaN    NaN
# a8b78ea7-159b-42bf-a2e5-98bc26987de2.fast5  24.0  15.0  31.0   52.0   29.0
# 3f74febf-1ec5-479f-b2b4-522fad358daa.fast5  15.0  25.0  37.0    6.0    NaN
# 255e006f-16ca-433e-8649-3aada74d9d1c.fast5   NaN   NaN   NaN    NaN    NaN
# d595c69e-0b1c-412f-a40e-c479a43f5300.fast5  23.0  41.0  99.0    6.0  193.0
# e3a14f4c-60a5-4cdf-8870-470a49ed093b.fast5   6.0  55.0  13.0    6.0    7.0
# 06ef4d57-98a5-4a88-9e01-a3a872340788.fast5   8.0  35.0  20.0    6.0   80.0
# 4f081c6d-c0c4-4488-a851-cd8a7f284e91.fast5   NaN   NaN   NaN    NaN    NaN
#
#                                             9170
# 13154b6e-f9cc-4e3b-8c2c-5f0fa43de9c2.fast5   NaN
# 1c498e5b-5e93-4cbe-baf2-8032a2e20ccb.fast5   NaN
# ebf6a522-8df0-48a9-a0ef-f4dcdde5339f.fast5   NaN
# b76ab61c-db0f-45d5-a65a-b40ce1296342.fast5  12.0
# 01f25e05-0219-430f-bc26-cb3948023adf.fast5   NaN
# e88e4d16-3908-4d11-8c94-fb64ad54266d.fast5   NaN
# 92f22b41-79b1-461f-b468-394d5352550d.fast5  15.0
# 1b050b90-add3-49b1-b6ea-d4c2a488817c.fast5   NaN
# 6348393f-6959-403b-a9d5-23b2ad7bd170.fast5  10.0
# 2beb0736-f2a1-44ad-9e3b-f8f2a99c940b.fast5   NaN
# 43a05c30-a583-4f33-9fbe-33623d874c67.fast5   NaN
# d31e9abf-0c52-4364-95ce-b4e30d8f1439.fast5   NaN
# e3d1a174-b44c-45f1-a4ed-5431930e6baa.fast5   NaN
# 1689f4d6-0725-4e84-bc2a-ff66734cd7f6.fast5   NaN
# f29865cd-8625-4799-8ad3-78a6d86ee762.fast5   NaN
# 074b8b7f-99ce-4403-ae62-1fdddc60f7a6.fast5   NaN
# ae7f89df-6b11-4b5e-8435-119904bc67e3.fast5   NaN
# 0f3275f2-a2bf-4ba2-873d-207e6b5e1c6d.fast5   NaN
# 2b42461d-4c3f-40ca-be61-99e4e1e2b64e.fast5   NaN
# fbadf6f3-79a5-4d2e-a332-74f00e139c4b.fast5   NaN
# 57826bc6-3acb-4902-b5ff-ce8331550b57.fast5  16.0
# 2828b3be-4685-431b-a662-a8343018dcb8.fast5   NaN
# eaa433b8-08af-4a24-b27c-2eb4ea7d9592.fast5   NaN
# b4bd83d6-7c9a-41ed-9e1a-7259cb3a50e0.fast5  13.0
# 888f41f3-4bcc-4327-bc45-5c9262f71997.fast5   NaN
# 9282c375-74df-42cb-9a85-b2bd64a1eaaa.fast5   NaN
# 2c301762-8522-4c5e-a077-69eb62370686.fast5   6.0
# dd7793fb-e022-41ae-ba21-aab2d38d3efc.fast5  14.0
# 754a5893-35a5-45e6-afac-4f503831c8a2.fast5   NaN
# d0cf16a5-ec5e-4b77-8653-a6e3fd3a3ef6.fast5   NaN
# ...                                          ...
# 8c63db92-d785-4299-a11b-da53a17994d0.fast5   NaN
# 69e49417-ac25-4221-9569-86ea8510978e.fast5   NaN
# b6ec3349-45c9-4406-83ae-66a3bcdbc763.fast5   NaN
# d0c7ac07-4705-4476-98de-5155fa1ede70.fast5   NaN
# 560ed0f2-d0f8-40f8-a55f-886b1a9c04f1.fast5   NaN
# da406fc7-da74-46cf-83e5-3a8cb2986e58.fast5   NaN
# 43e2551c-ef59-4db6-8e14-cc2abd8df31c.fast5   NaN
# 5e60f3d8-71d5-41bc-8e33-334a3def9209.fast5   NaN
# c0ab8740-b4df-4f57-b615-4f52d6116455.fast5   NaN
# c1afd570-ed94-41d8-a0fc-929d65ac813f.fast5   NaN
# 51d12b59-17db-42f9-a6a9-bbbc3cd341ee.fast5   NaN
# 3534bb36-5357-43e7-82bf-9f220a55ac98.fast5   NaN
# ddc27333-d9ab-4835-af7b-368e5390a405.fast5   NaN
# 6a16700c-b658-49a3-8662-832b87a47804.fast5   NaN
# 23c90439-1125-4a84-bf58-a236220b3e56.fast5   6.0
# 91da9691-5adf-4294-ae9d-40221286e342.fast5   NaN
# ecb902df-13aa-42bc-981f-155248106ae7.fast5   NaN
# 5e4c212f-080a-4165-ab10-c42df484a5d0.fast5   NaN
# d858aa09-a3b0-4b18-8205-7d006bd1db15.fast5   NaN
# 336f5264-d1a6-4d71-b1cc-4220523e2af2.fast5   NaN
# a1fe1777-ac94-4832-9daa-6edbdecb7fde.fast5   NaN
# 45d11beb-91ab-49f4-86d9-142bfeccb209.fast5  31.0
# 4936838e-9340-4497-bcf7-d41647d21372.fast5   NaN
# a8b78ea7-159b-42bf-a2e5-98bc26987de2.fast5   NaN
# 3f74febf-1ec5-479f-b2b4-522fad358daa.fast5   NaN
# 255e006f-16ca-433e-8649-3aada74d9d1c.fast5   NaN
# d595c69e-0b1c-412f-a40e-c479a43f5300.fast5   6.0
# e3a14f4c-60a5-4cdf-8870-470a49ed093b.fast5   NaN
# 06ef4d57-98a5-4a88-9e01-a3a872340788.fast5  48.0
# 4f081c6d-c0c4-4488-a851-cd8a7f284e91.fast5   NaN
#
# [398 rows x 9162 columns]

# %%
# compute dwell times
# This cell took about 60-90 minutes using 28 cores on the Owens cluster

dfs = {key: get_df_from_basedir(path) for key, path in paths.items()}

# %%
# write out to a CSV

for key, dframe in dfs.items():
    out_name = ('IVT_lengths.csv' if key == 'IVT'
                else 'Trizol_{}_lengths.csv'.format(key))
    dframe.to_csv(
        out_name,
        sep=',', # default
        na_rep='nan',
        header=True, # default
        index=True, # default
        index_label='read_id',
    )

# %%
for key, value in dfs.items():
    print(key, dfs[key].shape)
# Out:
# ('A', (398, 9162))
# ('IVT', (108918, 9170))
# ('C', (767, 9161))
# ('B', (660, 9162))
# ('OLD', (1662, 9164))
